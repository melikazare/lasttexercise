# %% [markdown]
# <a href="https://colab.research.google.com/github/melikazare/lasttexercise/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
messages= pd.read_csv('COVIID.CSV')
messages
# Out:
#                                                   review  sentiment
# 0      If you've recently heard from an old friend, y...          1
# 1      Dr. Hall says it makes sense that we would rea...          1
# 2      "Please, if you are going to protest, take car...          1
# 3      The Tulsa Health Department sent 2 Works for Y...          1
# 4      The industry is one of the hardest hit by the ...          0
# ...                                                  ...        ...
# 33319  Ferrer again walked through data from the past...          1
# 33320  We actually need to maintain, even more, our v...          1
# 33321  Democrats demanded a far larger bill, includin...          1
# 33322  RELATED: Trump says Americans can expect anoth...          1
# 33323  2 trillion, and while Trump's negotiators have...          1
#
# [33324 rows x 2 columns]

# %%
ps = PorterStemmer()
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['review'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
train, test = train_test_split(messages, test_size=0.2, random_state=42)

X_train = train['review']
y_train = train['sentiment']
X_test = test['review']
y_test = test['sentiment']

# %%
vectorizer = TfidfVectorizer(max_features=1000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
svm = SVC(kernel='linear')
svm.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.83
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76      2446
#            1       0.85      0.89      0.87      4219
#
#     accuracy                           0.83      6665
#    macro avg       0.82      0.81      0.81      6665
# weighted avg       0.83      0.83      0.83      6665
